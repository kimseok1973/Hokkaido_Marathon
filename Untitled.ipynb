# %%
using Distributions,Turing
using StatsPlots
# Out:
# ┌ Info: Precompiling StatsPlots [f3b207a7-027a-5e70-b257-86293d7955fd]
# └ @ Base loading.jl:1423

# %%
q4 = quantile(Gamma(3,1.5),0.4)
q2 = quantile(Gamma(3,1.5),0.2)
(q4,q2)
# Out:
# (3.427615356005071, 2.302566303966965)

# %%
plot(0:0.1:q4,Gamma(3,1.5),fill=(0,0.4,:orange),lw=0,label="quantile 40%")
plot!(Gamma(3,1.5),lw=2,label="Gamma dist",color=:blue)
plot!(ann=[(4,0.01,"q4=$(round(q4,digits=3))"),(2.5,0.1,"40%"),(11,0.07,"?=Gamma(k,θ)")])

# %%
savefig("gamma-question.png")

# %%
@model function gdemo()
    m ~ InverseGamma(2,3)
    s ~ InverseGamma(2,3)
    dist = Gamma(m,s)
    
    y4 ~ Normal(quantile(dist,0.4),0.1)
    y2 ~ Normal(quantile(dist,0.2),0.1)
    
    y4 ~ Normal(q4,0.1)
    y2 ~ Normal(q2,0.1)
end   

c = sample(gdemo(),NUTS(),6000)
# Out:
# MethodError: no method matching __gamma_inc_inv(::ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}, ::ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}, ::Bool)
# Closest candidates are:
#   __gamma_inc_inv(::T, ::T, ::Bool) where T<:Union{Float16, Float32} at C:\Users\kimse\.julia\packages\SpecialFunctions\hefUc\src\gamma_inc.jl:1089
#   __gamma_inc_inv(::Float64, ::Float64, ::Bool) at C:\Users\kimse\.julia\packages\SpecialFunctions\hefUc\src\gamma_inc.jl:1012
#
# Stacktrace:
#   [1] _gamma_inc_inv
#     @ C:\Users\kimse\.julia\packages\SpecialFunctions\hefUc\src\gamma_inc.jl:1009 [inlined]
#   [2] gamma_inc_inv
#     @ C:\Users\kimse\.julia\packages\SpecialFunctions\hefUc\src\gamma_inc.jl:991 [inlined]
#   [3] gammainvcdf(k::ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}, θ::ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}, p::Float64)
#     @ StatsFuns C:\Users\kimse\.julia\packages\StatsFuns\vxSkw\src\distrs\gamma.jl:98
#   [4] quantile
#     @ C:\Users\kimse\.julia\packages\Distributions\1PkiH\src\univariates.jl:627 [inlined]
#   [5] gdemo(__model__::DynamicPPL.Model{typeof(gdemo), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, __varinfo__::DynamicPPL.ThreadSafeVarInfo{DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}}}, ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Base.RefValue{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}}}, __context__::DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random._GLOBAL_RNG})
#     @ Main .\In[43]:6
#   [6] macro expansion
#     @ C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\model.jl:493 [inlined]
#   [7] _evaluate!!
#     @ C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\model.jl:476 [inlined]
#   [8] evaluate_threadsafe!!
#     @ C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\model.jl:467 [inlined]
#   [9] evaluate!!(model::DynamicPPL.Model{typeof(gdemo), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, varinfo::DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}}}, ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, context::DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random._GLOBAL_RNG})
#     @ DynamicPPL C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\model.jl:402
#  [10] evaluate!!
#     @ C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\model.jl:415 [inlined]
#  [11] evaluate!!
#     @ C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\model.jl:423 [inlined]
#  [12] LogDensityFunction
#     @ C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\Turing.jl:37 [inlined]
#  [13] vector_mode_dual_eval!
#     @ C:\Users\kimse\.julia\packages\ForwardDiff\pDtsf\src\apiutils.jl:37 [inlined]
#  [14] vector_mode_gradient!(result::DiffResults.MutableDiffResult{1, Float64, Tuple{Vector{Float64}}}, f::Turing.LogDensityFunction{DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Model{typeof(gdemo), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext}, x::Vector{Float64}, cfg::ForwardDiff.GradientConfig{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}})
#     @ ForwardDiff C:\Users\kimse\.julia\packages\ForwardDiff\pDtsf\src\gradient.jl:113
#  [15] gradient!
#     @ C:\Users\kimse\.julia\packages\ForwardDiff\pDtsf\src\gradient.jl:37 [inlined]
#  [16] gradient!(result::DiffResults.MutableDiffResult{1, Float64, Tuple{Vector{Float64}}}, f::Turing.LogDensityFunction{DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Model{typeof(gdemo), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext}, x::Vector{Float64}, cfg::ForwardDiff.GradientConfig{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}})
#     @ ForwardDiff C:\Users\kimse\.julia\packages\ForwardDiff\pDtsf\src\gradient.jl:35
#  [17] gradient_logp(ad::Turing.Essential.ForwardDiffAD{0, true}, θ::Vector{Float64}, vi::DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, model::DynamicPPL.Model{typeof(gdemo), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, sampler::DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, context::DynamicPPL.DefaultContext)
#     @ Turing.Essential C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\essential\ad.jl:130
#  [18] gradient_logp (repeats 2 times)
#     @ C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\essential\ad.jl:88 [inlined]
#  [19] ∂logπ∂θ
#     @ C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\hmc.jl:433 [inlined]
#  [20] ∂H∂θ
#     @ C:\Users\kimse\.julia\packages\AdvancedHMC\51xgc\src\hamiltonian.jl:31 [inlined]
#  [21] phasepoint
#     @ C:\Users\kimse\.julia\packages\AdvancedHMC\51xgc\src\hamiltonian.jl:76 [inlined]
#  [22] phasepoint(rng::Random._GLOBAL_RNG, θ::Vector{Float64}, h::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, Turing.LogDensityFunction{DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Model{typeof(gdemo), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext}, Turing.Inference.var"#∂logπ∂θ#53"{DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.Model{typeof(gdemo), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}}})
#     @ AdvancedHMC C:\Users\kimse\.julia\packages\AdvancedHMC\51xgc\src\hamiltonian.jl:153
#  [23] initialstep(rng::Random._GLOBAL_RNG, model::DynamicPPL.Model{typeof(gdemo), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, spl::DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, vi::DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}; init_params::Nothing, nadapts::Int64, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ Turing.Inference C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\hmc.jl:167
#  [24] step(rng::Random._GLOBAL_RNG, model::DynamicPPL.Model{typeof(gdemo), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, spl::DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}; resume_from::Nothing, init_params::Nothing, kwargs::Base.Pairs{Symbol, Int64, Tuple{Symbol}, NamedTuple{(:nadapts,), Tuple{Int64}}})
#     @ DynamicPPL C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\sampler.jl:104
#  [25] macro expansion
#     @ C:\Users\kimse\.julia\packages\AbstractMCMC\fnRmh\src\sample.jl:120 [inlined]
#  [26] macro expansion
#     @ C:\Users\kimse\.julia\packages\ProgressLogging\6KXlp\src\ProgressLogging.jl:328 [inlined]
#  [27] (::AbstractMCMC.var"#21#22"{Bool, String, Nothing, Int64, Int64, Base.Pairs{Symbol, Int64, Tuple{Symbol}, NamedTuple{(:nadapts,), Tuple{Int64}}}, Random._GLOBAL_RNG, DynamicPPL.Model{typeof(gdemo), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, Int64, Int64})()
#     @ AbstractMCMC C:\Users\kimse\.julia\packages\AbstractMCMC\fnRmh\src\logging.jl:12
#  [28] with_logstate(f::Function, logstate::Any)
#     @ Base.CoreLogging .\logging.jl:511
#  [29] with_logger(f::Function, logger::LoggingExtras.TeeLogger{Tuple{LoggingExtras.EarlyFilteredLogger{ConsoleProgressMonitor.ProgressLogger, AbstractMCMC.var"#1#3"{Module}}, LoggingExtras.EarlyFilteredLogger{Base.CoreLogging.SimpleLogger, AbstractMCMC.var"#2#4"{Module}}}})
#     @ Base.CoreLogging .\logging.jl:623
#  [30] with_progresslogger(f::Function, _module::Module, logger::Base.CoreLogging.SimpleLogger)
#     @ AbstractMCMC C:\Users\kimse\.julia\packages\AbstractMCMC\fnRmh\src\logging.jl:36
#  [31] macro expansion
#     @ C:\Users\kimse\.julia\packages\AbstractMCMC\fnRmh\src\logging.jl:11 [inlined]
#  [32] mcmcsample(rng::Random._GLOBAL_RNG, model::DynamicPPL.Model{typeof(gdemo), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, sampler::DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, N::Int64; progress::Bool, progressname::String, callback::Nothing, discard_initial::Int64, thinning::Int64, chain_type::Type, kwargs::Base.Pairs{Symbol, Int64, Tuple{Symbol}, NamedTuple{(:nadapts,), Tuple{Int64}}})
#     @ AbstractMCMC C:\Users\kimse\.julia\packages\AbstractMCMC\fnRmh\src\sample.jl:111
#  [33] sample(rng::Random._GLOBAL_RNG, model::DynamicPPL.Model{typeof(gdemo), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, sampler::DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, N::Int64; chain_type::Type, resume_from::Nothing, progress::Bool, nadapts::Int64, discard_adapt::Bool, discard_initial::Int64, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ Turing.Inference C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\hmc.jl:133
#  [34] sample
#     @ C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\hmc.jl:116 [inlined]
#  [35] #sample#2
#     @ C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\Inference.jl:145 [inlined]
#  [36] sample
#     @ C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\Inference.jl:145 [inlined]
#  [37] #sample#1
#     @ C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\Inference.jl:135 [inlined]
#  [38] sample(model::DynamicPPL.Model{typeof(gdemo), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, alg::NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}, N::Int64)
#     @ Turing.Inference C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\Inference.jl:135
#  [39] top-level scope
#     @ In[43]:13
#  [40] eval
#     @ .\boot.jl:373 [inlined]
#  [41] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base .\loading.jl:1196

# %% [markdown]
# MethodError: no method matching __gamma_inc_inv(::ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}, ::ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}, ::Bool)
# Closest candidates are:
#   __gamma_inc_inv(::T, ::T, ::Bool) where T<:Union{Float16, Float32} at C:\Users\xxxxxx\.julia\packages\SpecialFunctions\hefUc\src\gamma_inc.jl:1089
#   __gamma_inc_inv(::Float64, ::Float64, ::Bool) at C:\Users\xxxxxx\.julia\packages\SpecialFunctions\hefUc\src\gamma_inc.jl:1012
#
# Stacktrace:....省略

# %%
using ForwardDiff,StatsFuns,SpecialFunctions
function SpecialFunctions.__gamma_inc_inv(a::ForwardDiff.Dual{T}, minpq::ForwardDiff.Dual{T}, pcase::Bool) where {T}
    
    v_a= ForwardDiff.value(a)
    v_pq = ForwardDiff.value(minpq)
    p_a = ForwardDiff.partials(a).values
    p_pq = ForwardDiff.partials(minpq).values

    SpecialFunctions.__gamma_inc_inv(v_a,v_pq,pcase)
end

# %%
@model function gdemo()
    m ~ InverseGamma(2,3)
    s ~ InverseGamma(2,3)
    dist = Gamma(m,s)
    
    y4 ~ Normal(quantile(dist,0.4),0.1)
    y2 ~ Normal(quantile(dist,0.2),0.1)
    
    y4 ~ Normal(q4,0.1) #q4 is a constance , 3.4276
    y2 ~ Normal(q2,0.1) #q2 is a constance , 2.3025
end   

c = sample(gdemo(),NUTS(),6000)
# Out:
# ┌ Info: Found initial step size
# │   ϵ = 0.2
# └ @ Turing.Inference C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\hmc.jl:188
# Sampling: 100%|█████████████████████████████████████████| Time: 0:01:02
# Chains MCMC chain (6000×16×1 Array{Float64, 3}):
#
# Iterations        = 1001:1:7000
# Number of chains  = 1
# Samples per chain = 6000
# Wall duration     = 65.96 seconds
# Compute duration  = 65.96 seconds
# parameters        = m, s, y4, y2
# internals         = lp, n_steps, is_accept, acceptance_rate, log_density, hamiltonian_energy, hamiltonian_energy_error, max_hamiltonian_energy_error, tree_depth, numerical_error, step_size, nom_step_size
#
# Summary Statistics
#   parameters      mean       std   naive_se      mcse       ess      rhat   es ⋯
#       Symbol   Float64   Float64    Float64   Float64   Float64   Float64      ⋯
#
#            m    3.0844    0.8489     0.0110    0.0841   46.3321    1.0234      ⋯
#            s    1.6008    0.5086     0.0066    0.0485   52.3757    1.0242      ⋯
#           y4    3.4174    0.0934     0.0012    0.0082   81.4606    1.0015      ⋯
#           y2    2.2963    0.0919     0.0012    0.0084   50.0436    1.0302      ⋯
#                                                                 1 column omitted
#
# Quantiles
#   parameters      2.5%     25.0%     50.0%     75.0%     97.5%
#       Symbol   Float64   Float64   Float64   Float64   Float64
#
#            m    1.9430    2.4611    2.8759    3.5576    5.0975
#            s    0.7607    1.2086    1.5787    1.9368    2.6341
#           y4    3.2258    3.3583    3.4174    3.4802    3.6048
#           y2    2.1220    2.2297    2.3011    2.3585    2.4747

# %%
c4 = cdf(Gamma(3, 1.5),3.482)
c2 = cdf(Gamma(3, 1.5),2.3)
(c2,c4)
# Out:
# (0.19956583512797052, 0.40961042158376443)

# %%
@model function gdemo2()
    m ~ InverseGamma(2,3)
    s ~ InverseGamma(2,3)
    dist = Gamma(m,s)
    
    y4 ~ Normal(cdf(dist,3.382),0.1)
    y2 ~ Normal(cdf(dist,2.3),0.1)
    
    y4 ~ Normal(c4,0.1) #c4 is a constance , 0.409610
    y2 ~ Normal(c2,0.1) #c2 is a constance , 0.199565
end   

c2 = sample(gdemo2(),NUTS(),6000)
# Out:
# MethodError: no method matching _gamma_inc(::ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}, ::ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}, ::Int64)
# Closest candidates are:
#   _gamma_inc(::Float64, ::Float64, ::Integer) at C:\Users\kimse\.julia\packages\SpecialFunctions\hefUc\src\gamma_inc.jl:860
#   _gamma_inc(::BigFloat, ::BigFloat, ::Integer) at C:\Users\kimse\.julia\packages\SpecialFunctions\hefUc\src\gamma_inc.jl:950
#   _gamma_inc(::Float32, ::Float32, ::Integer) at C:\Users\kimse\.julia\packages\SpecialFunctions\hefUc\src\gamma_inc.jl:956
#   ...
#
# Stacktrace:
#   [1] gamma_inc(a::ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}, x::Float64, ind::Int64)
#     @ SpecialFunctions C:\Users\kimse\.julia\packages\SpecialFunctions\hefUc\src\gamma_inc.jl:858
#   [2] gamma_inc(a::ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}, d::ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}, ind::Int64)
#     @ ForwardDiff C:\Users\kimse\.julia\packages\ForwardDiff\pDtsf\src\dual.jl:771
#   [3] gamma_inc(a::ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}, x::ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4})
#     @ SpecialFunctions C:\Users\kimse\.julia\packages\SpecialFunctions\hefUc\src\gamma_inc.jl:858
#   [4] gammacdf(k::ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}, θ::ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}, x::ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4})
#     @ StatsFuns C:\Users\kimse\.julia\packages\StatsFuns\vxSkw\src\distrs\gamma.jl:34
#   [5] gammacdf
#     @ C:\Users\kimse\.julia\packages\StatsFuns\vxSkw\src\distrs\gamma.jl:36 [inlined]
#   [6] cdf
#     @ C:\Users\kimse\.julia\packages\Distributions\1PkiH\src\univariates.jl:622 [inlined]
#   [7] gdemo2(__model__::DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, __varinfo__::DynamicPPL.ThreadSafeVarInfo{DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}}}, ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Base.RefValue{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}}}, __context__::DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random._GLOBAL_RNG})
#     @ Main .\In[49]:6
#   [8] macro expansion
#     @ C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\model.jl:493 [inlined]
#   [9] _evaluate!!
#     @ C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\model.jl:476 [inlined]
#  [10] evaluate_threadsafe!!
#     @ C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\model.jl:467 [inlined]
#  [11] evaluate!!(model::DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, varinfo::DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}}}, ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, context::DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random._GLOBAL_RNG})
#     @ DynamicPPL C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\model.jl:402
#  [12] evaluate!!
#     @ C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\model.jl:415 [inlined]
#  [13] evaluate!!
#     @ C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\model.jl:423 [inlined]
#  [14] LogDensityFunction
#     @ C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\Turing.jl:37 [inlined]
#  [15] vector_mode_dual_eval!
#     @ C:\Users\kimse\.julia\packages\ForwardDiff\pDtsf\src\apiutils.jl:37 [inlined]
#  [16] vector_mode_gradient!(result::DiffResults.MutableDiffResult{1, Float64, Tuple{Vector{Float64}}}, f::Turing.LogDensityFunction{DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext}, x::Vector{Float64}, cfg::ForwardDiff.GradientConfig{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}})
#     @ ForwardDiff C:\Users\kimse\.julia\packages\ForwardDiff\pDtsf\src\gradient.jl:113
#  [17] gradient!
#     @ C:\Users\kimse\.julia\packages\ForwardDiff\pDtsf\src\gradient.jl:37 [inlined]
#  [18] gradient!(result::DiffResults.MutableDiffResult{1, Float64, Tuple{Vector{Float64}}}, f::Turing.LogDensityFunction{DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext}, x::Vector{Float64}, cfg::ForwardDiff.GradientConfig{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}})
#     @ ForwardDiff C:\Users\kimse\.julia\packages\ForwardDiff\pDtsf\src\gradient.jl:35
#  [19] gradient_logp(ad::Turing.Essential.ForwardDiffAD{0, true}, θ::Vector{Float64}, vi::DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, model::DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, sampler::DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, context::DynamicPPL.DefaultContext)
#     @ Turing.Essential C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\essential\ad.jl:130
#  [20] gradient_logp (repeats 2 times)
#     @ C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\essential\ad.jl:88 [inlined]
#  [21] ∂logπ∂θ
#     @ C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\hmc.jl:433 [inlined]
#  [22] ∂H∂θ
#     @ C:\Users\kimse\.julia\packages\AdvancedHMC\51xgc\src\hamiltonian.jl:31 [inlined]
#  [23] phasepoint
#     @ C:\Users\kimse\.julia\packages\AdvancedHMC\51xgc\src\hamiltonian.jl:76 [inlined]
#  [24] phasepoint(rng::Random._GLOBAL_RNG, θ::Vector{Float64}, h::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, Turing.LogDensityFunction{DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext}, Turing.Inference.var"#∂logπ∂θ#53"{DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}}})
#     @ AdvancedHMC C:\Users\kimse\.julia\packages\AdvancedHMC\51xgc\src\hamiltonian.jl:153
#  [25] initialstep(rng::Random._GLOBAL_RNG, model::DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, spl::DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, vi::DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}; init_params::Nothing, nadapts::Int64, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ Turing.Inference C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\hmc.jl:167
#  [26] step(rng::Random._GLOBAL_RNG, model::DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, spl::DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}; resume_from::Nothing, init_params::Nothing, kwargs::Base.Pairs{Symbol, Int64, Tuple{Symbol}, NamedTuple{(:nadapts,), Tuple{Int64}}})
#     @ DynamicPPL C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\sampler.jl:104
#  [27] macro expansion
#     @ C:\Users\kimse\.julia\packages\AbstractMCMC\fnRmh\src\sample.jl:120 [inlined]
#  [28] macro expansion
#     @ C:\Users\kimse\.julia\packages\ProgressLogging\6KXlp\src\ProgressLogging.jl:328 [inlined]
#  [29] (::AbstractMCMC.var"#21#22"{Bool, String, Nothing, Int64, Int64, Base.Pairs{Symbol, Int64, Tuple{Symbol}, NamedTuple{(:nadapts,), Tuple{Int64}}}, Random._GLOBAL_RNG, DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, Int64, Int64})()
#     @ AbstractMCMC C:\Users\kimse\.julia\packages\AbstractMCMC\fnRmh\src\logging.jl:12
#  [30] with_logstate(f::Function, logstate::Any)
#     @ Base.CoreLogging .\logging.jl:511
#  [31] with_logger(f::Function, logger::LoggingExtras.TeeLogger{Tuple{LoggingExtras.EarlyFilteredLogger{ConsoleProgressMonitor.ProgressLogger, AbstractMCMC.var"#1#3"{Module}}, LoggingExtras.EarlyFilteredLogger{Base.CoreLogging.SimpleLogger, AbstractMCMC.var"#2#4"{Module}}}})
#     @ Base.CoreLogging .\logging.jl:623
#  [32] with_progresslogger(f::Function, _module::Module, logger::Base.CoreLogging.SimpleLogger)
#     @ AbstractMCMC C:\Users\kimse\.julia\packages\AbstractMCMC\fnRmh\src\logging.jl:36
#  [33] macro expansion
#     @ C:\Users\kimse\.julia\packages\AbstractMCMC\fnRmh\src\logging.jl:11 [inlined]
#  [34] mcmcsample(rng::Random._GLOBAL_RNG, model::DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, sampler::DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, N::Int64; progress::Bool, progressname::String, callback::Nothing, discard_initial::Int64, thinning::Int64, chain_type::Type, kwargs::Base.Pairs{Symbol, Int64, Tuple{Symbol}, NamedTuple{(:nadapts,), Tuple{Int64}}})
#     @ AbstractMCMC C:\Users\kimse\.julia\packages\AbstractMCMC\fnRmh\src\sample.jl:111
#  [35] sample(rng::Random._GLOBAL_RNG, model::DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, sampler::DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, N::Int64; chain_type::Type, resume_from::Nothing, progress::Bool, nadapts::Int64, discard_adapt::Bool, discard_initial::Int64, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ Turing.Inference C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\hmc.jl:133
#  [36] sample
#     @ C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\hmc.jl:116 [inlined]
#  [37] #sample#2
#     @ C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\Inference.jl:145 [inlined]
#  [38] sample
#     @ C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\Inference.jl:145 [inlined]
#  [39] #sample#1
#     @ C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\Inference.jl:135 [inlined]
#  [40] sample(model::DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, alg::NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}, N::Int64)
#     @ Turing.Inference C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\Inference.jl:135
#  [41] top-level scope
#     @ In[49]:13
#  [42] eval
#     @ .\boot.jl:373 [inlined]
#  [43] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base .\loading.jl:1196

# %% [markdown]
# MethodError: no method matching _gamma_inc(::ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}, ::ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}, ::Int64)
# Closest candidates are:
#   _gamma_inc(::Float64, ::Float64, ::Integer) at C:\Users\kimse\.julia\packages\SpecialFunctions\hefUc\src\gamma_inc.jl:860
#   _gamma_inc(::BigFloat, ::BigFloat, ::Integer) at C:\Users\kimse\.julia\packages\SpecialFunctions\hefUc\src\gamma_inc.jl:950
#   _gamma_inc(::Float32, ::Float32, ::Integer) at C:\Users\kimse\.julia\packages\SpecialFunctions\hefUc\src\gamma_inc.jl:956
#   ...

# %%
function SpecialFunctions._gamma_inc(a::ForwardDiff.Dual{T}, x::ForwardDiff.Dual{T}, ind::Integer) where {T}
     v_a= ForwardDiff.value(a)
    v_x = ForwardDiff.value(x)
    SpecialFunctions._gamma_inc(v_a,v_x,ind)
end

# %%
@model function gdemo2()
    m ~ InverseGamma(2,3)
    s ~ InverseGamma(2,3)
    dist = Gamma(m,s)
    
    y4 ~ Normal(cdf(dist,3.382),0.1)
    y2 ~ Normal(cdf(dist,2.3),0.1)
    
    y4 ~ Normal(c4,0.1) #c4 is a constance , 0.409610
    y2 ~ Normal(c2,0.1) #c2 is a constance , 0.199565
end   

c2 = sample(gdemo2(),NUTS(),6000)
# Out:
# TypeError: in new, expected NTuple{4, Float64}, got a value of type NTuple{4, ForwardDiff.Dual{Nothing, Float64, 4}}
#
# Stacktrace:
#   [1] Partials
#     @ C:\Users\kimse\.julia\packages\ForwardDiff\pDtsf\src\partials.jl:2 [inlined]
#   [2] convert
#     @ C:\Users\kimse\.julia\packages\ForwardDiff\pDtsf\src\partials.jl:74 [inlined]
#   [3] convert
#     @ C:\Users\kimse\.julia\packages\ForwardDiff\pDtsf\src\dual.jl:431 [inlined]
#   [4] setproperty!
#     @ .\Base.jl:43 [inlined]
#   [5] setindex!
#     @ .\refvalue.jl:57 [inlined]
#   [6] acclogp!!
#     @ C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\threadsafe.jl:19 [inlined]
#   [7] tilde_assume!!(context::DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random._GLOBAL_RNG}, right::Normal{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}, 4}}, vn::AbstractPPL.VarName{:y4, Setfield.IdentityLens}, vi::DynamicPPL.ThreadSafeVarInfo{DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}}}, ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Base.RefValue{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}}})
#     @ DynamicPPL C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\context_implementations.jl:118
#   [8] gdemo2(__model__::DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, __varinfo__::DynamicPPL.ThreadSafeVarInfo{DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}}}, ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Base.RefValue{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}}}, __context__::DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random._GLOBAL_RNG})
#     @ Main .\In[54]:6
#   [9] macro expansion
#     @ C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\model.jl:493 [inlined]
#  [10] _evaluate!!
#     @ C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\model.jl:476 [inlined]
#  [11] evaluate_threadsafe!!
#     @ C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\model.jl:467 [inlined]
#  [12] evaluate!!(model::DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, varinfo::DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, Vector{Set{DynamicPPL.Selector}}}}}, ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}, context::DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random._GLOBAL_RNG})
#     @ DynamicPPL C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\model.jl:402
#  [13] evaluate!!
#     @ C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\model.jl:415 [inlined]
#  [14] evaluate!!
#     @ C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\model.jl:423 [inlined]
#  [15] LogDensityFunction
#     @ C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\Turing.jl:37 [inlined]
#  [16] vector_mode_dual_eval!
#     @ C:\Users\kimse\.julia\packages\ForwardDiff\pDtsf\src\apiutils.jl:37 [inlined]
#  [17] vector_mode_gradient!(result::DiffResults.MutableDiffResult{1, Float64, Tuple{Vector{Float64}}}, f::Turing.LogDensityFunction{DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext}, x::Vector{Float64}, cfg::ForwardDiff.GradientConfig{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}})
#     @ ForwardDiff C:\Users\kimse\.julia\packages\ForwardDiff\pDtsf\src\gradient.jl:113
#  [18] gradient!
#     @ C:\Users\kimse\.julia\packages\ForwardDiff\pDtsf\src\gradient.jl:37 [inlined]
#  [19] gradient!(result::DiffResults.MutableDiffResult{1, Float64, Tuple{Vector{Float64}}}, f::Turing.LogDensityFunction{DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext}, x::Vector{Float64}, cfg::ForwardDiff.GradientConfig{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.TuringTag, Float64}, Float64, 4}}})
#     @ ForwardDiff C:\Users\kimse\.julia\packages\ForwardDiff\pDtsf\src\gradient.jl:35
#  [20] gradient_logp(ad::Turing.Essential.ForwardDiffAD{0, true}, θ::Vector{Float64}, vi::DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, model::DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, sampler::DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, context::DynamicPPL.DefaultContext)
#     @ Turing.Essential C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\essential\ad.jl:130
#  [21] gradient_logp (repeats 2 times)
#     @ C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\essential\ad.jl:88 [inlined]
#  [22] ∂logπ∂θ
#     @ C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\hmc.jl:433 [inlined]
#  [23] ∂H∂θ
#     @ C:\Users\kimse\.julia\packages\AdvancedHMC\51xgc\src\hamiltonian.jl:31 [inlined]
#  [24] phasepoint
#     @ C:\Users\kimse\.julia\packages\AdvancedHMC\51xgc\src\hamiltonian.jl:76 [inlined]
#  [25] phasepoint(rng::Random._GLOBAL_RNG, θ::Vector{Float64}, h::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, Turing.LogDensityFunction{DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext}, Turing.Inference.var"#∂logπ∂θ#53"{DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}}})
#     @ AdvancedHMC C:\Users\kimse\.julia\packages\AdvancedHMC\51xgc\src\hamiltonian.jl:153
#  [26] initialstep(rng::Random._GLOBAL_RNG, model::DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, spl::DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, vi::DynamicPPL.TypedVarInfo{NamedTuple{(:m, :s, :y4, :y2), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:m, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:m, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s, Setfield.IdentityLens}, Int64}, Vector{InverseGamma{Float64}}, Vector{AbstractPPL.VarName{:s, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y4, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y4, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:y2, Setfield.IdentityLens}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:y2, Setfield.IdentityLens}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}; init_params::Nothing, nadapts::Int64, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ Turing.Inference C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\hmc.jl:167
#  [27] step(rng::Random._GLOBAL_RNG, model::DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, spl::DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}; resume_from::Nothing, init_params::Nothing, kwargs::Base.Pairs{Symbol, Int64, Tuple{Symbol}, NamedTuple{(:nadapts,), Tuple{Int64}}})
#     @ DynamicPPL C:\Users\kimse\.julia\packages\DynamicPPL\1qg3U\src\sampler.jl:104
#  [28] macro expansion
#     @ C:\Users\kimse\.julia\packages\AbstractMCMC\fnRmh\src\sample.jl:120 [inlined]
#  [29] macro expansion
#     @ C:\Users\kimse\.julia\packages\ProgressLogging\6KXlp\src\ProgressLogging.jl:328 [inlined]
#  [30] (::AbstractMCMC.var"#21#22"{Bool, String, Nothing, Int64, Int64, Base.Pairs{Symbol, Int64, Tuple{Symbol}, NamedTuple{(:nadapts,), Tuple{Int64}}}, Random._GLOBAL_RNG, DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, Int64, Int64})()
#     @ AbstractMCMC C:\Users\kimse\.julia\packages\AbstractMCMC\fnRmh\src\logging.jl:12
#  [31] with_logstate(f::Function, logstate::Any)
#     @ Base.CoreLogging .\logging.jl:511
#  [32] with_logger(f::Function, logger::LoggingExtras.TeeLogger{Tuple{LoggingExtras.EarlyFilteredLogger{ConsoleProgressMonitor.ProgressLogger, AbstractMCMC.var"#1#3"{Module}}, LoggingExtras.EarlyFilteredLogger{Base.CoreLogging.SimpleLogger, AbstractMCMC.var"#2#4"{Module}}}})
#     @ Base.CoreLogging .\logging.jl:623
#  [33] with_progresslogger(f::Function, _module::Module, logger::Base.CoreLogging.SimpleLogger)
#     @ AbstractMCMC C:\Users\kimse\.julia\packages\AbstractMCMC\fnRmh\src\logging.jl:36
#  [34] macro expansion
#     @ C:\Users\kimse\.julia\packages\AbstractMCMC\fnRmh\src\logging.jl:11 [inlined]
#  [35] mcmcsample(rng::Random._GLOBAL_RNG, model::DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, sampler::DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, N::Int64; progress::Bool, progressname::String, callback::Nothing, discard_initial::Int64, thinning::Int64, chain_type::Type, kwargs::Base.Pairs{Symbol, Int64, Tuple{Symbol}, NamedTuple{(:nadapts,), Tuple{Int64}}})
#     @ AbstractMCMC C:\Users\kimse\.julia\packages\AbstractMCMC\fnRmh\src\sample.jl:111
#  [36] sample(rng::Random._GLOBAL_RNG, model::DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, sampler::DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, N::Int64; chain_type::Type, resume_from::Nothing, progress::Bool, nadapts::Int64, discard_adapt::Bool, discard_initial::Int64, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ Turing.Inference C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\hmc.jl:133
#  [37] sample
#     @ C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\hmc.jl:116 [inlined]
#  [38] #sample#2
#     @ C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\Inference.jl:145 [inlined]
#  [39] sample
#     @ C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\Inference.jl:145 [inlined]
#  [40] #sample#1
#     @ C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\Inference.jl:135 [inlined]
#  [41] sample(model::DynamicPPL.Model{typeof(gdemo2), (), (), (), Tuple{}, Tuple{}, DynamicPPL.DefaultContext}, alg::NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}, N::Int64)
#     @ Turing.Inference C:\Users\kimse\.julia\packages\Turing\Tpj0b\src\inference\Inference.jl:135
#  [42] top-level scope
#     @ In[54]:13
#  [43] eval
#     @ .\boot.jl:373 [inlined]
#  [44] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base .\loading.jl:1196
